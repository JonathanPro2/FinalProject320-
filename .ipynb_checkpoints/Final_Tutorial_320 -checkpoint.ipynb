# %% [markdown]
# # Data Science Pipeline Tutorial - Analyzing a COVID-19 Dataset
# #### Jonathan Probert, Akash Shetty, Selena Xiao

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this tutorial, we will go through the data science pipeline, including data scraping, cleaning, exploration through visualization, hypothesis testing, and machine learning, in order to gain some insight from this dataset.

# %% [markdown]
# ## Importing packages
# We need to use some Python libraries for storing, visualizing, and analyzing our dataset.

# %%
# Storing
import pandas as pd 
import numpy as np 

# Visualizing
import matplotlib.pyplot as plt
import seaborn 

# Linear regression, machine learning, and Hypothesis Testing
import statsmodels.api as sm 

import sklearn.ensemble 
import sklearn.model_selection 
import sklearn.metrics
from sklearn.linear_model import LinearRegression

from statsmodels.stats.proportion import proportions_ztest

# %% [markdown]
# ## Data Scraping

# %% [markdown]
# The dataset that we are using is located at https://covid.ourworldindata.org/data/owid-covid-data.csv
#
# It updates daily, so we are using the dataset as it was downloaded on May 03, 2021.
#
# The dataset's README at https://github.com/owid/covid-19-data/tree/master/public/data shows that it contains daily records for cases, deaths, and health statistics for every country in the world.

# %%
data = pd.read_csv('owid-covid-data.csv') 
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Besides daily information for each country, the data also contains daily information for each continent as well as the entire world. We remove the rows that contain a non-country value as its location. This is represented in the data as a iso_code starting with OWID.

# %%
# deleting references to world data (wrl)
data = data[data.iso_code != 'OWID_WRL']

# # deleting references to Africa (afr)
data = data[data.iso_code != 'OWID_AFR']

# # deleting references to Asia (asi)
data = data[data.iso_code != 'OWID_ASI']

# # deleting references to Europe and EU (EUR and EUN)
data = data[data.iso_code != 'OWID_EUR']
data = data[data.iso_code != 'OWID_EUN']

# # deleting references to North America (nam)
data = data[data.iso_code != 'OWID_NAM']

# # deleting references to Oceania (oce)
data = data[data.iso_code != 'OWID_OCE']

# # deleting references to South America (sam)  
data = data[data.iso_code != 'OWID_SAM']

# %% [markdown]
# Additionally, for initial data exploration, we will only be looking at cases and deaths for the top 50 most populous countries on May 3rd 2021. We drop the unneeded columns.

# %%
# Sorting the data by population, we will only look at the top 50 most populous countries
data = data.sort_values(by=['population'] , ascending = False) 

# remove data columns that will not be used
data = data.drop(columns=['reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 
                         'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_icu_admissions_per_million', 
                         'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests', 
                         'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 
                         'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case', 'tests_units', 
                         'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations', 
                         'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 
                         'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million', 
                         'stringency_index', 'population_density', 'median_age', 'aged_65_older', 'aged_70_older', 
                         'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate', 'diabetes_prevalence', 
                         'female_smokers', 'male_smokers', 'hospital_beds_per_thousand', 
                         'life_expectancy', 'human_development_index', 'handwashing_facilities'])

data = data.drop(columns=['new_cases_smoothed', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 
                         'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 
                         'new_deaths_smoothed_per_million'])


# getting the data for the latest date available (5/3/2021)
top_50 = data[data.date == '2021-05-03']
top_50 = top_50.head(50)

# create new columns for the averages of new deaths and new cases
# iter through rows of top_50 using the location to get the mean of all new cases/new deaths from that location
avg_new_cases = []
for index, row in top_50.iterrows():
    avg_new_cases.append(data[data.location == row['location']]['new_cases'].mean())
    
avg_new_deaths = []
for index, row in top_50.iterrows():
    avg_new_deaths.append(data[data.location == row['location']]['new_deaths'].mean())
    
# add new columns to top_50
top_50['avg_new_cases'] = avg_new_cases
top_50['avg_new_deaths'] = avg_new_deaths

# remove new cases and new deaths columns as they are only for may 3
top_50= top_50.drop(columns=['new_deaths', 'new_cases'])
# remove date because data spans more than just this date
top_50 = top_50.drop(columns=['date'])


top_50
# Out:
#       iso_code      continent                      location  total_cases  \
# 16713      CHN           Asia                         China     102549.0
# 35734      IND           Asia                         India   20282833.0
# 81797      USA  North America                 United States   32472201.0
# 36162      IDN           Asia                     Indonesia    1682004.0
# 59235      PAK           Asia                      Pakistan     837523.0
# 11434      BRA  South America                        Brazil   14779529.0
# 56466      NGA         Africa                       Nigeria     165199.0
# 7106       BGD           Asia                    Bangladesh     763682.0
# 64039      RUS         Europe                        Russia    4776844.0
# 50338      MEX  North America                        Mexico    2349900.0
# 39808      JPN           Asia                         Japan     609625.0
# 26005      ETH         Africa                      Ethiopia     258813.0
# ...

# %% [markdown]
# ## Data Exploration and Visualization
#
# Data exploration is an important step because it provides an idea on relationships that might exist within the data. This helps guide our data analysis with hypothesis testing and machine learning.

# %% [markdown]
# The data contains a column dedicated to total deaths for each country. Let's start by visualizing that.

# %%
# Plotting the total deaths of the top 50 most populated countries from covid-19 

death = top_50.plot(x="iso_code", y="total_deaths", kind="bar", figsize = (15, 15), title = "Total deaths from Covid-19") 
death.set_xlabel("Countries")
death.set_ylabel("total deaths")
# Out:
# Text(0, 0.5, 'total deaths')

# %% [markdown]
# Similarly, we can also visualize the column for total cases

# %%
# Plotting the total cases of the top 50 most populated countries from covid-19 


cases = top_50.plot(x="iso_code", y="total_cases", kind="bar", figsize = (15, 15), title = "Total cases from Covid-19") 
cases.set_xlabel("Countries")
cases.set_ylabel("total cases")
# Out:
# Text(0, 0.5, 'total cases')

# %% [markdown]
# While looking at total deaths and cases can give insight into how much a country has been affected, it doesn't take into account the population of that country. For example, Country A may have only 1000 cases, which is miniscule when compared to 1 million cases in Country B. However, Country A may have a population of 10000, while Country B has a population of a billion. In that case, Country A has a larger proportion of its population that has been impacted by COVID.
#
# Even though we are only looking at the top 50 most populous countries, this difference between totals and population is still important. The most populous in our top_50 list, China, has a 1.4 billion population, while the least populous, Venezuela is 28 million. We think this difference in population is large enough, so let's visualize proportion of deaths and cases next.

# %%
# adds the proportion of total cases and total deaths compared to the population of the country to top_50
proportion_of_total_cases = []
proportion_of_total_deaths = []
for index, row in top_50.iterrows():
    proportion_of_total_cases.append(row['total_cases'] / row['population'])
    proportion_of_total_deaths.append(row['total_deaths'] / row['population'])
    
top_50['total_cases / population'] = proportion_of_total_cases
top_50['total_deaths / population'] = proportion_of_total_deaths
top_50
# Out:
#       iso_code      continent                      location  total_cases  \
# 16713      CHN           Asia                         China     102549.0
# 35734      IND           Asia                         India   20282833.0
# 81797      USA  North America                 United States   32472201.0
# 36162      IDN           Asia                     Indonesia    1682004.0
# 59235      PAK           Asia                      Pakistan     837523.0
# 11434      BRA  South America                        Brazil   14779529.0
# 56466      NGA         Africa                       Nigeria     165199.0
# 7106       BGD           Asia                    Bangladesh     763682.0
# 64039      RUS         Europe                        Russia    4776844.0
# 50338      MEX  North America                        Mexico    2349900.0
# 39808      JPN           Asia                         Japan     609625.0
# 26005      ETH         Africa                      Ethiopia     258813.0
# ...

# %%
# Plotting the cases / population of the top 50 most populated countries from covid-19 

cases_ratio = top_50.plot(x="iso_code", y="total_cases / population", kind="bar", figsize = (15, 15), title = "Covid-19 cases with respect to countries population") 
cases_ratio.set_xlabel("Countries")
cases_ratio.set_ylabel("total cases")
# Out:
# Text(0, 0.5, 'total cases')

# %%
# Plotting the deaths / population of the top 50 most populated countries from covid-19

death_ratio = top_50.plot(x="iso_code", y="total_deaths / population", kind="bar", figsize = (15, 15), title = "Covid-19 deaths with respect to countries population") 
death_ratio.set_xlabel("Countries")
death_ratio.set_ylabel("total deaths")
# Out:
# Text(0, 0.5, 'total deaths')

# %% [markdown]
# Our previous visualizations for total deaths/cases and proportion of deaths/cases provides insight on how the top 50 most populous countries have been impacted so far by the pandemic.
#
# In the data cleaning step, we added a column for the average amount of new deaths and new cases for each country. This average gives a clue on how much cases and deaths will increase in the future - how each country will be impacted.

# %%
avg_new_deaths_plot = top_50.plot(x="iso_code", y="avg_new_deaths", kind="bar", figsize = (15, 15), title = "Average new deaths for COVID-19") 
avg_new_deaths_plot.set_xlabel("Countries")
avg_new_deaths_plot.set_ylabel("Average amount of new deaths")
# Out:
# Text(0, 0.5, 'Average amount of new deaths')

# %%
avg_new_cases_plot = top_50.plot(x="iso_code", y="avg_new_cases", kind="bar", figsize = (15, 15), title = "Average new cases for COVID-19") 
avg_new_cases_plot.set_xlabel("Countries")
avg_new_cases_plot.set_ylabel("Average amount of new cases")
# Out:
# Text(0, 0.5, 'Average amount of new cases')

# %% [markdown]
# ## Hypothesis Testing
#
#
#
# Our graphs from the total cases and deaths have a similar outcome as those of the average new cases and deaths. Since this is the case it will be the case that the proportion of total deaths and total cases to population will more accurately represent how well certain countries did compared to others. Of the countries with the highest proportions, we will conduct hypothesis tests with the following hypothesis test formulas:
#
# a = 0.05
#
# Ho: proportion of cases/deaths from country1 = proportion of cases/deaths from country2
#
# Ha: proportion of cases/deaths from country1 != proportion of cases/deaths from country2
#
# If we reject the null hypothesis it means that country 1 has a different proportion of cases/deaths to population, and if this happens it means that the country with the higher proportion has been hit harder by COVID-19

# %%
sort_by_cases_prop = top_50.sort_values(by=['total_cases / population'], ascending=False)
    
hypothesis_of_cases = []
for i in range(49):
    sig = 0.05 # for 2 sided
    
    sample_succ_a, sample_size_a = (sort_by_cases_prop.iloc[i]['total_cases'], sort_by_cases_prop.iloc[i]['population'])
    sample_succ_b, sample_size_b = (sort_by_cases_prop.iloc[i+1]['total_cases'], sort_by_cases_prop.iloc[i+1]['population'])
    
    successes = np.array([sample_succ_a, sample_succ_b])
    samples = np.array([sample_size_a, sample_size_b])
    
    stat, pvalue = proportions_ztest(count=successes, nobs=samples,  alternative='two-sided')
    
    if pvalue > sig: reject_check = 'fail to reject for ' + sort_by_cases_prop.iloc[i]['location'] + " versus " + sort_by_cases_prop.iloc[i+1]['location']
    else: reject_check = 'reject null hypothesis for ' + sort_by_cases_prop.iloc[i]['location'] + " versus " + sort_by_cases_prop.iloc[i+1]['location']
    
    hypothesis_of_cases.append(reject_check)
    
hypothesis_of_cases
# Out:
# ['reject null hypothesis for United States versus France',
#  'reject null hypothesis for France versus Spain',
#  'reject null hypothesis for Spain versus Poland',
#  'reject null hypothesis for Poland versus Brazil',
#  'reject null hypothesis for Brazil versus Italy',
#  'reject null hypothesis for Italy versus Argentina',
#  'reject null hypothesis for Argentina versus United Kingdom',
#  'reject null hypothesis for United Kingdom versus Turkey',
#  'reject null hypothesis for Turkey versus Colombia',
#  'reject null hypothesis for Colombia versus Peru',
#  'reject null hypothesis for Peru versus Ukraine',
#  'reject null hypothesis for Ukraine versus Germany',
#  'reject null hypothesis for Germany versus Canada',
#  'reject null hypothesis for Canada versus Russia',
#  'reject null hypothesis for Russia versus Iran',
#  'reject null hypothesis for Iran versus Iraq',
#  'reject null hypothesis for Iraq versus South Africa',
# ...

# %%
sort_by_deaths_prop = top_50.sort_values(by=['total_deaths / population'], ascending=False)
    
hypothesis_of_deaths = []
for i in range(49):
    sig = 0.025 # for 2 sided
    
    sample_succ_a, sample_size_a = (sort_by_cases_prop.iloc[i]['total_deaths'], sort_by_cases_prop.iloc[i]['population'])
    sample_succ_b, sample_size_b = (sort_by_cases_prop.iloc[i+1]['total_deaths'], sort_by_cases_prop.iloc[i+1]['population'])
    
    successes = np.array([sample_succ_a, sample_succ_b])
    samples = np.array([sample_size_a, sample_size_b])
    
    stat, pvalue = proportions_ztest(count=successes, nobs=samples,  alternative='two-sided')
    
    if pvalue > sig: reject_check = 'fail to reject for ' + sort_by_cases_prop.iloc[i]['location'] + " versus " + sort_by_cases_prop.iloc[i+1]['location']
    else: reject_check = 'reject null hypothesis for ' + sort_by_cases_prop.iloc[i]['location'] + " versus " + sort_by_cases_prop.iloc[i+1]['location']
    
    hypothesis_of_deaths.append(reject_check)
    
    
hypothesis_of_deaths
# Out:
# ['reject null hypothesis for United States versus France',
#  'reject null hypothesis for France versus Spain',
#  'reject null hypothesis for Spain versus Poland',
#  'reject null hypothesis for Poland versus Brazil',
#  'reject null hypothesis for Brazil versus Italy',
#  'reject null hypothesis for Italy versus Argentina',
#  'reject null hypothesis for Argentina versus United Kingdom',
#  'reject null hypothesis for United Kingdom versus Turkey',
#  'reject null hypothesis for Turkey versus Colombia',
#  'reject null hypothesis for Colombia versus Peru',
#  'reject null hypothesis for Peru versus Ukraine',
#  'reject null hypothesis for Ukraine versus Germany',
#  'reject null hypothesis for Germany versus Canada',
#  'reject null hypothesis for Canada versus Russia',
#  'reject null hypothesis for Russia versus Iran',
#  'reject null hypothesis for Iran versus Iraq',
#  'reject null hypothesis for Iraq versus South Africa',
# ...

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# In our Data Exploration and Visualization, we looked at average new cases as a way to "predict" how cases will increase in the future for each country.
#
# A more robust way to actually predict future case counts is through machine learning. Due to the amount of countries in our sample lets look at the top three countries (China, India, USA) and the bottom three countries (Yemen, Nepal, Venezuala) within the 50 countries we have already selected. To predict the daily cases for the six countries we are looking at we are going to use a polynomial regression for the six countries as opposed to a linear regression. Using Polynomial regression is more appropriate due to the nature of the graphs because of the many critical points within each of the daily cases graphs. For the Polynomial regression, lets have the regression  completed with a degree of n = 4.

# %%
orig_data = pd.read_csv('owid-covid-data.csv')

# getting the daily data for the top three countries in population (China, India, USA)
chn_data = orig_data[orig_data.iso_code == 'CHN'] 
ind_data = orig_data[orig_data.iso_code == 'IND']
usa_data = orig_data[orig_data.iso_code == 'USA']

# getting the daily data for the top three countries in population (Yemen, Nepal, Venezuala)
yem_data = orig_data[orig_data.iso_code == 'YEM']
npl_data = orig_data[orig_data.iso_code == 'NPL']
ven_data = orig_data[orig_data.iso_code == 'VEN']

# %%
from sklearn.preprocessing import PolynomialFeatures 

# gathering the data for the China daily cases as well as the days since the outbreak started 
chn_data = chn_data.iloc[1:]
china_cases = np.array(chn_data["new_cases"]).reshape(-1, 1)
china_days = np.arange(chn_data.shape[0]).reshape(-1, 1) 

# training the poly regression model for the china data 
china_poly = PolynomialFeatures(degree = 4)
china_x_poly = china_poly.fit_transform(china_days)
china_lin = LinearRegression() 
china_lin.fit(china_x_poly, china_cases)


plt.figure(figsize = (10,10))
plt.plot(china_days, china_lin.predict(china_poly.fit_transform(china_days)), label = "Regression Model Prediction")
plt.plot(china_days, china_cases, label = "Daily Cases") 
plt.title("Daily Covid-19 Cases in China since the outbreak")
plt.xlabel("Days Since Covid Arrived in China")
plt.ylabel("Daily Cases")
plt.legend() 
plt.show()

# %% [markdown]
# For the Poly Regression model for China, it appears that it can predict the future cases with some accuracy but earlier, before day 100, the regression model is a poor representation of the Covid daily cases within China. Perhaps a larger degree for the poly regression model will solve this misrepresenatation.

# %%
# gathering the data for the India daily cases as well as the days since the outbreak started 
ind_data = ind_data.iloc[1:]
india_cases = np.array(ind_data["new_cases"]).reshape(-1, 1)
india_days = np.arange(ind_data.shape[0]).reshape(-1, 1) 


# training the poly regression model for the India data
india_poly = PolynomialFeatures(degree = 4)
india_x_poly = india_poly.fit_transform(india_days)
india_lin = LinearRegression() 
india_lin.fit(india_x_poly, india_cases)


plt.figure(figsize = (10,10))
plt.plot(india_days, india_lin.predict(india_poly.fit_transform(india_days)))
plt.plot(india_days, india_cases) 
plt.title("Daily Covid-19 Cases in India since the outbreak")
plt.xlabel("Days Since Covid Arrived in India")
plt.ylabel("Daily Cases")
plt.show()

# %%
# gathering the data for the USA daily cases as well as the days since the outbreak started  
usa_data = usa_data.iloc[1:]
usa_cases = np.array(usa_data["new_cases"]).reshape(-1, 1)
usa_days = np.arange(usa_data.shape[0]).reshape(-1, 1) 

# training the poly regression model for the USA data
usa_poly = PolynomialFeatures(degree = 4)
usa_x_poly = usa_poly.fit_transform(usa_days)
usa_lin = LinearRegression() 
usa_lin.fit(usa_x_poly, usa_cases)


plt.figure(figsize = (10,10))
plt.plot(usa_days, usa_lin.predict(usa_poly.fit_transform(usa_days)), label = "Regression Model Prediction")
plt.plot(usa_days, usa_cases, label = "Daily Cases") 
plt.title("Daily Covid-19 Cases in the USA since the outbreak")
plt.xlabel("Days Since Covid Arrived in the USA")
plt.ylabel("Daily Cases")
plt.legend()
plt.show()

# %%
# gathering the data for the Yemen daily cases as well as the days since the outbreak started  
yem_data = yem_data.iloc[1:]
yem_cases = np.array(yem_data["new_cases"]).reshape(-1, 1)
yem_days = np.arange(yem_data.shape[0]).reshape(-1, 1) 

# training the poly regression model for the Yemen data
yem_poly = PolynomialFeatures(degree = 4)
yem_x_poly = yem_poly.fit_transform(yem_days)
yem_lin = LinearRegression() 
yem_lin.fit(yem_x_poly, yem_cases)


plt.figure(figsize = (10,10))
plt.plot(yem_days, yem_lin.predict(yem_poly.fit_transform(yem_days)), label = "Regression Model Prediction")
plt.plot(yem_days, yem_cases, label = "Daily Cases") 
plt.title("Daily Covid-19 Cases in Yemen since the outbreak")
plt.xlabel("Days Since Covid Arrived in Yemen")
plt.ylabel("Daily Cases")
plt.legend()
plt.show()

# %%
# gathering the data for the Nepal daily cases as well as the days since the outbreak started 
npl_data = npl_data.iloc[1:]
npl_cases = np.array(npl_data["new_cases"]).reshape(-1, 1)
npl_days = np.arange(npl_data.shape[0]).reshape(-1, 1) 


# training the poly regression model for the Nepal data
npl_poly = PolynomialFeatures(degree = 4)
npl_x_poly = npl_poly.fit_transform(npl_days)
npl_lin = LinearRegression() 
npl_lin.fit(npl_x_poly, npl_cases)


plt.figure(figsize = (10,10))
plt.plot(npl_days, npl_lin.predict(npl_poly.fit_transform(npl_days)), label = "Regression Model Prediction")
plt.plot(npl_days, npl_cases, label = "Daily Cases") 
plt.title("Daily Covid-19 Cases in Nepal since the outbreak")
plt.xlabel("Days Since Covid Arrived in Nepal")
plt.ylabel("Daily Cases")
plt.legend()
plt.show()

# %%
# gathering the data for the Venezuala daily cases as well as the days since the outbreak started  
ven_data = ven_data.iloc[1:]
ven_cases = np.array(ven_data["new_cases"]).reshape(-1, 1)
ven_days = np.arange(ven_data.shape[0]).reshape(-1, 1) 

# training the poly regression model for the Venezuala data
ven_poly = PolynomialFeatures(degree = 4)
ven_x_poly = ven_poly.fit_transform(ven_days)
ven_lin = LinearRegression() 
ven_lin.fit(ven_x_poly, ven_cases)


plt.figure(figsize = (10,10))
plt.plot(ven_days, ven_lin.predict(ven_poly.fit_transform(ven_days)), label = "Regression Model Prediction")
plt.plot(ven_days, ven_cases, label = "Daily Cases") 
plt.title("Daily Covid-19 Cases in Venezuala since the outbreak")
plt.xlabel("Days Since Covid Arrived in Venezuala")
plt.ylabel("Daily Cases")
plt.legend()
plt.show()

# %% [markdown]
# From the multiple graphs showing the different poly regressions for each of the varying countries some of the poly regressions such as India and Venezuala where shown to be representitive of the daily cases and could be used to predict the future cases based on the data currently availible. However for countries such as China and Yemen, the poly regression was not representitive of the daily cases for the countries. Increasing, the poly regression degree may solve this issue. This goes to show that picking the correct degree for Poly regression is important for data analysis especially for data with this many fluctuations for all countries.
